# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Po ying\Documents\GitHub\COGS108_Repo\testing.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Po%20ying/Documents/GitHub/COGS108_Repo/testing.ipynb#ch0000000?line=0'>1</a> import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
